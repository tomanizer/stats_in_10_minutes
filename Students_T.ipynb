# %% [markdown]
# <a href="https://colab.research.google.com/github/tomanizer/stats_in_10_minutes/blob/master/Students_T.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Student's T
#
# The Student's t-distribution was developed by William Sealy Gosset under the pseudonym Student.

# %%
#@title
import numpy as np
from scipy.stats import norm, t
import plotly.graph_objects as go

# %%
fig = go.Figure()
dt = np.linspace(start=-10, stop=10, num=500)

# %%
#@title Gaussian vs Student T { run: "auto" }
#@markdown #####Normal
gaussian_std = 1  #@param {type: "slider", min: 1, max: 10}

#@markdown #####Student-t
decrees_of_freedom = 1  #@param {type: "slider", min: 1, max: 10}

std_normal = norm.pdf(dt, 0, gaussian_std)
student_t = t.pdf(x=dt, df=decrees_of_freedom, loc=0, scale=1)

if fig.data == ():
  fig.add_scatter(x=dt, y=[], name='standard normal')
  fig.add_scatter(x=dt, y=[], name=f'student-t {decrees_of_freedom} dgf')

fig.data[0].y = std_normal
fig.data[1].y = student_t
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9b45c72c-b896-4ff0-8487-38037ff924af" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9b45c72c-b896-4ff0-8487-38037ff924af")) {
#                     Plotly.newPlot(
#                         '9b45c72c-b896-4ff0-8487-38037ff924af',
#                         [{"name": "standard normal", "type": "scatter", "x": [-10.0, -9.959919839679358, -9.919839679358718, -9.879759519038076, -9.839679358717435, -9.799599198396793, -9.759519038076153, -9.719438877755511, -9.67935871743487, -9.639278557114228, -9.599198396793588, -9.559118236472946, -9.519038076152304, -9.478957915831664, -9.438877755511022, -9.39879759519038, -9.358717434869739, -9.318637274549099, -9.278557114228457, -9.238476953907815, -9.198396793587175, -9.158316633266534, -9.118236472945892, -9.07815631262525, -9.03807615230461, -8.997995991983968, -8.957915831663327, -8.917835671342685, -8.877755511022045, -8.837675350701403, -8.797595190380761, -8.75751503006012, -8.71743486973948, -8.677354709418838, -8.637274549098196, -8.597194388777556, -8.557114228456914, -8.517034068136272, -8.47695390781563, -8.43687374749499, -8.396793587174349, -8.356713426853707, -8.316633266533067, -8.276553106212425, -8.236472945891784, -8.196392785571142, -8.156312625250502, -8.11623246492986, -8.076152304609218, -8.036072144288577, -7.9959919839679365, -7.955911823647295, -7.915831663326653, -7.875751503006012, -7.835671342685371, -7.7955911823647295, -7.755511022044088, -7.715430861723447, -7.675350701402806, -7.635270541082164, -7.595190380761523, -7.555110220440882, -7.515030060120241, -7.474949899799599, -7.434869739478958, -7.394789579158317, -7.354709418837675, -7.314629258517034, -7.274549098196393, -7.234468937875752, -7.19438877755511, -7.154308617234469, -7.114228456913828, -7.074148296593187, -7.034068136272545, -6.993987975951904, -6.953907815631263, -6.913827655310621, -6.8737474949899795, -6.833667334669339, -6.793587174348698, -6.753507014028056, -6.713426853707415, -6.673346693386774, -6.6332665330661325, -6.593186372745491, -6.55310621242485, -6.513026052104209, -6.472945891783567, -6.432865731462925, -6.3927855711422845, -6.352705410821644, -6.312625250501002, -6.272545090180361, -6.23246492985972, -6.192384769539078, -6.152304609218437, -6.112224448897796, -6.072144288577155, -6.032064128256513, -5.991983967935872, -5.95190380761523, -5.9118236472945895, -5.871743486973948, -5.831663326653307, -5.791583166332665, -5.751503006012024, -5.711422845691383, -5.671342685370742, -5.631262525050101, -5.591182364729459, -5.551102204408818, -5.511022044088176, -5.470941883767535, -5.430861723446894, -5.390781563126253, -5.350701402805611, -5.31062124248497, -5.270541082164329, -5.2304609218436875, -5.190380761523047, -5.150300601202405, -5.110220440881764, -5.070140280561122, -5.030060120240481, -4.98997995991984, -4.949899799599199, -4.909819639278557, -4.869739478957916, -4.829659318637275, -4.789579158316633, -4.7494989979959925, -4.709418837675351, -4.66933867735471, -4.629258517034068, -4.589178356713427, -4.5490981963927855, -4.509018036072145, -4.468937875751503, -4.428857715430862, -4.388777555110221, -4.348697394789579, -4.308617234468938, -4.268537074148297, -4.228456913827656, -4.188376753507014, -4.148296593186373, -4.108216432865731, -4.0681362725450905, -4.028056112224449, -3.987975951903808, -3.947895791583167, -3.907815631262525, -3.8677354709418843, -3.8276553106212425, -3.7875751503006017, -3.74749498997996, -3.707414829659319, -3.6673346693386772, -3.6272545090180364, -3.5871743486973955, -3.5470941883767537, -3.507014028056113, -3.466933867735471, -3.42685370741483, -3.3867735470941884, -3.3466933867735476, -3.306613226452906, -3.266533066132265, -3.226452905811623, -3.1863727454909823, -3.1462925851703414, -3.1062124248496996, -3.0661322645290587, -3.026052104208417, -2.985971943887776, -2.9458917835671343, -2.9058116232464934, -2.8657314629258517, -2.825651302605211, -2.785571142284569, -2.745490981963928, -2.7054108216432873, -2.6653306613226455, -2.6252505010020046, -2.585170340681363, -2.545090180360722, -2.50501002004008, -2.4649298597194393, -2.4248496993987976, -2.3847695390781567, -2.344689378757515, -2.304609218436874, -2.264529058116233, -2.2244488977955914, -2.1843687374749505,  ...

# %% [markdown]
# # Deriving Student's t
#
# The recipe for Student's t is as follows:
#
# 1. Draw samples from a normal distribution

# %%
mu = 0
std = 1
samplesize = 20
sample_from_normal = np.random.normal(mu,std, samplesize)
sample_from_normal
# Out:
# array([ 0.27694146, -1.47655275,  2.62345118,  1.81709297,  1.24356739,
#         1.44237429, -0.4274136 ,  0.20014058, -0.96994631, -0.14211196,
#        -0.92716166, -1.30787689,  1.23075739,  0.60244228, -1.17452245,
#         0.04862965, -1.22170955,  0.55981615, -1.02743764,  0.74759388])

# %% [markdown]
# 2. Calculate sample mean and sample variance

# %%
sample_mean = sample_from_normal.mean()
print(f"Sample mean: {sample_mean}")
sample_var = sample_from_normal.var()
print(f"Sample variance: {sample_var}")
# Out:
# Sample mean: 0.10590372123908813
# Sample variance: 1.31388906960349

# %% [markdown]
# 3. Define a random variable for the *Student's t statistic*

# %%
random_variable = (sample_mean - mu) / (sample_var / np.sqrt(samplesize))
random_variable
# Out:
# 0.36046866548977996

# %% [markdown]
# 4. Create a function to let us draw many samples of this random variable

# %%
def studentt_random_variable(n=100, samplesize=20, mu=0, std=1):
  sample_from_normal = np.random.normal(mu,std, (n, samplesize))
  sample_mean = sample_from_normal.mean(axis=1)
  sample_var = sample_from_normal.var(axis=1)
  random_variable = (sample_mean - mu) / (sample_var / np.sqrt(samplesize))
  return sorted(random_variable)

# %%
#@title Simulate Student's t { run: "auto" }

n = 444  #@param {type: "slider", min: 10, max: 500}
samplesize = 5  #@param {type: "slider", min: 1, max: 200}
xval = studentt_random_variable(n=n, samplesize=samplesize)

fig1 = go.Figure()
fig1.add_histogram(x= xval, 
                   name='student t', 
                   histnorm="probability density")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d1460816-0797-46c4-9040-58c860a58673" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d1460816-0797-46c4-9040-58c860a58673")) {
#                     Plotly.newPlot(
#                         'd1460816-0797-46c4-9040-58c860a58673',
#                         [{"histnorm": "probability density", "name": "student t", "type": "histogram", "x": [-20.592425053545252, -15.258625138211105, -12.066487181865153, -10.728977299891287, -10.68596661217807, -9.12671948106018, -8.98645656925185, -8.494362686329763, -7.918131926103544, -7.906505535932219, -7.225866289316964, -5.956909278389933, -5.737591604889464, -5.4323620098786005, -5.424240985332243, -5.3866431793867715, -5.003214745331712, -4.961818105229587, -4.926827622879465, -4.91272026123416, -4.826815495826792, -4.801390318539828, -4.696168143354225, -4.278988396747389, -4.27832304245844, -4.237884796853381, -4.060555804492053, -3.8659671845780905, -3.864743454861873, -3.838243421530058, -3.4029589089327437, -3.353588863458315, -3.274068200470865, -3.205554716411769, -3.116090856787406, -3.0997502659901843, -3.0579676249987715, -3.002094104858746, -2.979993813235844, -2.9479266124335095, -2.834767318286233, -2.707540052510177, -2.670740214319363, -2.663412136179277, -2.659502146990029, -2.6313020997586074, -2.550944562820537, -2.527143833817885, -2.4641778313950304, -2.4282263086777727, -2.3715384563700583, -2.3201545195081774, -2.286227831031692, -2.2813808445362245, -2.133497888731042, -1.9981664461624749, -1.9492104884213752, -1.9052926505048404, -1.9039021999605816, -1.858483808590741, -1.8567242322945858, -1.833160380159407, -1.7310012942800574, -1.7182199471816857, -1.7102170884905612, -1.6604749431933141, -1.6535933095017747, -1.6452588602814535, -1.6175706042574156, -1.604532403338726, -1.5841441348365248, -1.5838045608550768, -1.5788920468191194, -1.547856965148507, -1.522787900592634, -1.4764622232445892, -1.4581870521487938, -1.4451317339321557, -1.4355501072228636, -1.3687970958166638, -1.366006729720922, -1.361533808594087, -1.360902969915472, -1.3574739051732123, -1.3528448276258547, -1.350994681061453, -1.3150573286916953, -1.3116332242221052, -1.306328741232651, -1.3004901760646197, -1.274341246456531, -1.2260964237555079, -1.2234566558394135, -1.223250943815779, -1.1977628697331704, -1.1749651259967955, -1.1684339316966308, -1.148808893447922, -1.1466863264972846, -1.129723251051015, -1.1151568051614056, -1.1115736856816611, -1.102464334950764, -1.0701112072693184, -1.0585002067788585, -1.057085424600182, -1.0412406606568516, -1.0210825894981124, -1.005413372123378, -0.9984543059975676, -0.9947670229691845, -0.9870751172347034, -0.9643896705166882, -0.9581880324461138, -0.9395307325697299, -0.9388039387220093, -0.9387807602823275, -0.9274789858001802, -0.9094219864844153, -0.9071071829404024, -0.8855827577529669, -0.880039944547631, -0.8657844722414902, -0.8485816063229181, -0.8437734330866606, -0.8306789371033566, -0.8189562641090613, -0.8155502350404242, -0.8039736289882543, -0.7955299427640328, -0.7865191398985278, -0.7616706951498007, -0.7570182360881386, -0.7157036589428173, -0.7038948033121734, -0.7003461602339532, -0.6969082388236805, -0.6921152709608588, -0.6886959773385231, -0.6602828851551492, -0.6591287615969991, -0.6559138602205777, -0.5970963368500727, -0.5929695563957916, -0.5839226546411449, -0.5703248478804389, -0.5599213897409437, -0.5361404915444284, -0.534898029221718, -0.5322190729360575, -0.526524360659453, -0.5225956457916278, -0.5203353046455166, -0.5164987305678667, -0.5117844771000198, -0.5093140438687446, -0.4938582957785518, -0.4841445119422218, -0.4714572469501484, -0.4651955632199623, -0.46293473128577534, -0.4560338569043742, -0.4552421256087098, -0.4545163512970234, -0.45440219252297553, -0.44066363230417427, -0.4315167012404587, -0.4312614829139172, -0.4279170842869788, -0.4218515097068957, -0.4182029361084587, -0.414415645306919, -0.41142840436853506, -0.4105127464316303, -0.40035975722365846, -0.39797871091061876, -0.3860843563327928, -0.38425683989030107, -0.3810206382116573, -0.3775505840915653, -0.35840574248815915, -0.3411241227333561, -0.33234608033835594, -0.3268097258274253, -0.3266604532354702, -0.32496670828371305, -0.3188968359351373, -0.31627276718168 ...

# %%
#@title
